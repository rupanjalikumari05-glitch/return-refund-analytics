# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customers = pd.read_csv("customers.csv")
products = pd.read_csv("products.csv")
orders = pd.read_csv("orders.csv")
returns = pd.read_csv("returns.csv")

# %%
df = orders.merge(returns, on="order_id", how="left")
df = df.merge(products, on="product_id", how="left")
df = df.merge(customers, on="customer_id", how="left")

df.head()
# Out:
#    order_id  customer_id  product_id                  order_date  quantity  \
# 0         1          405        1082  2025-10-14 19:32:05.263656         3
# 1         2          449        1734  2024-11-25 19:32:05.263691         1
# 2         3          725         311  2025-02-28 19:32:05.263705         3
# 3         4          444        1841  2025-04-29 19:32:05.263715         2
# 4         5         1472        1132  2025-12-31 19:32:05.263724         2
#
#    price_per_unit  total_amount payment_method  return_id return_date  ...  \
# 0         1722.58       5167.74    Credit Card        NaN         NaN  ...
# 1          673.19        673.19         Wallet        NaN         NaN  ...
# 2         1383.13       4149.39     Debit Card        NaN         NaN  ...
# 3         2474.97       4949.94    Credit Card        NaN         NaN  ...
# 4         2520.33       5040.66    Credit Card        NaN         NaN  ...
#
#         product_name category   brand cost_price  selling_price  \
# 0  BrandD Jeans 1082  T-Shirt  BrandD    1448.84        1722.58
# 1  BrandC Shoes 1734  Sweater  BrandE    1844.50         673.19
# 2  BrandD Shorts 311    Jeans  BrandD    1554.21        1383.13
# 3  BrandB Skirt 1841  Sweater  BrandD     787.81        2474.97
# 4  BrandE Jeans 1132  Sweater  BrandA    1535.79        2520.33
#
#     customer_name  gender age     city                   join_date
# 0      Ava Garcia    Male  22  Kolkata  2023-11-12 19:32:05.208751
# 1      John Davis    Male  25    Surat  2025-12-25 19:32:05.208953
# 2  Isabella Brown  Female  60  Lucknow  2024-08-02 19:32:05.210844
# 3   Sophia Garcia  Female  52    Surat  2024-08-01 19:32:05.208933
# 4    Mason Miller  Female  32    Surat  2026-01-22 19:32:05.214592
#
# [5 rows x 21 columns]

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x="return_reason")
plt.title("Return Reasons Distribution")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x="category")
plt.title("Returns by Category")
plt.xticks(rotation=45)
plt.show()
